# %%
import tensorflow as tf
# Out:
# C:\Users\Rahul\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import iris_data

# %%
a,b=iris_data.load_data()
# Out:
# Downloading data from http://download.tensorflow.org/data/iris_training.csv
# 8192/2194 [================================================================================================================] - 0s 0us/step
# Downloading data from http://download.tensorflow.org/data/iris_test.csv
# 8192/573 [============================================================================================================================================================================================================================================================================================================================================================================================================================================] - 0s 0us/step

# %%
train_x=a[0]
train_x
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 0            6.4         2.8          5.6         2.2
# 1            5.0         2.3          3.3         1.0
# 2            4.9         2.5          4.5         1.7
# 3            4.9         3.1          1.5         0.1
# 4            5.7         3.8          1.7         0.3
# 5            4.4         3.2          1.3         0.2
# 6            5.4         3.4          1.5         0.4
# 7            6.9         3.1          5.1         2.3
# 8            6.7         3.1          4.4         1.4
# 9            5.1         3.7          1.5         0.4
# 10           5.2         2.7          3.9         1.4
# 11           6.9         3.1          4.9         1.5
# 12           5.8         4.0          1.2         0.2
# 13           5.4         3.9          1.7         0.4
# 14           7.7         3.8          6.7         2.2
# 15           6.3         3.3          4.7         1.6
# 16           6.8         3.2          5.9         2.3
# 17           7.6         3.0          6.6         2.1
# 18           6.4         3.2          5.3         2.3
# 19           5.7         4.4          1.5         0.4
# 20           6.7         3.3          5.7         2.1
# 21           6.4         2.8          5.6         2.1
# 22           5.4         3.9          1.3         0.4
# 23           6.1         2.6          5.6         1.4
# 24           7.2         3.0          5.8         1.6
# 25           5.2         3.5          1.5         0.2
# 26           5.8         2.6          4.0         1.2
# 27           5.9         3.0          5.1         1.8
# 28           5.4         3.0          4.5         1.5
# 29           6.7         3.0          5.0         1.7
# ..           ...         ...          ...         ...
# 90           6.5         3.0          5.2         2.0
# 91           6.1         2.8          4.7         1.2
# 92           5.1         3.5          1.4         0.3
# 93           4.6         3.1          1.5         0.2
# 94           6.5         3.0          5.8         2.2
# 95           4.6         3.4          1.4         0.3
# 96           4.6         3.2          1.4         0.2
# 97           7.7         2.8          6.7         2.0
# 98           5.9         3.2          4.8         1.8
# 99           5.1         3.8          1.6         0.2
# 100          4.9         3.0          1.4         0.2
# 101          4.9         2.4          3.3         1.0
# 102          4.5         2.3          1.3         0.3
# 103          5.8         2.7          4.1         1.0
# 104          5.0         3.4          1.6         0.4
# 105          5.2         3.4          1.4         0.2
# 106          5.3         3.7          1.5         0.2
# 107          5.0         3.6          1.4         0.2
# 108          5.6         2.9          3.6         1.3
# 109          4.8         3.1          1.6         0.2
# 110          6.3         2.7          4.9         1.8
# 111          5.7         2.8          4.1         1.3
# 112          5.0         3.0          1.6         0.2
# 113          6.3         3.3          6.0         2.5
# 114          5.0         3.5          1.6         0.6
# 115          5.5         2.6          4.4         1.2
# 116          5.7         3.0          4.2         1.2
# 117          4.4         2.9          1.4         0.2
# 118          4.8         3.0          1.4         0.1
# 119          5.5         2.4          3.7         1.0
#
# [120 rows x 4 columns]

# %%
train_y=a[1]
train_y
# Out:
# 0      2
# 1      1
# 2      2
# 3      0
# 4      0
# 5      0
# 6      0
# 7      2
# 8      1
# 9      0
# 10     1
# 11     1
# 12     0
# 13     0
# 14     2
# 15     1
# 16     2
# 17     2
# 18     2
# 19     0
# 20     2
# 21     2
# 22     0
# 23     2
# 24     2
# 25     0
# 26     1
# 27     2
# 28     1
# 29     1
#       ..
# 90     2
# 91     1
# 92     0
# 93     0
# 94     2
# 95     0
# 96     0
# 97     2
# 98     1
# 99     0
# 100    0
# 101    1
# 102    0
# 103    1
# 104    0
# 105    0
# 106    0
# 107    0
# 108    1
# 109    0
# 110    2
# 111    1
# 112    0
# 113    2
# 114    0
# 115    1
# 116    1
# 117    0
# 118    0
# 119    1
# Name: Species, Length: 120, dtype: int64

# %%
test_x=b[0]
test_y=b[1]

# %%
my_feature_columns=[]
for key in train_x.keys():
    my_feature_columns.append(tf.feature_column.numeric_column(key=key))

# %%
my_feature_columns
# Out:
# [_NumericColumn(key='SepalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='SepalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='PetalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='PetalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
classifier=tf.estimator.DNNClassifier(feature_columns=my_feature_columns,
                                      hidden_units=[10,10],
                                      n_classes=3)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Rahul\AppData\Local\Temp\tmp810wk18k
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Rahul\\AppData\\Local\\Temp\\tmp810wk18k', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000021679CFA390>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
classifier.train(input_fn=lambda :iris_data.train_input_fn(train_x,train_y,1),steps=500)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Rahul\AppData\Local\Temp\tmpy5ov2u4a\model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 200 into C:\Users\Rahul\AppData\Local\Temp\tmpy5ov2u4a\model.ckpt.
# INFO:tensorflow:loss = 0.9484036, step = 201
# INFO:tensorflow:global_step/sec: 444.285
# INFO:tensorflow:loss = 0.8779188, step = 301 (0.232 sec)
# INFO:tensorflow:global_step/sec: 736.546
# INFO:tensorflow:loss = 0.035129745, step = 401 (0.130 sec)
# INFO:tensorflow:global_step/sec: 841.328
# INFO:tensorflow:loss = 0.024048652, step = 501 (0.119 sec)
# INFO:tensorflow:global_step/sec: 737.56
# INFO:tensorflow:loss = 0.019630091, step = 601 (0.135 sec)
# INFO:tensorflow:Saving checkpoints for 700 into C:\Users\Rahul\AppData\Local\Temp\tmpy5ov2u4a\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.18776712.

# %%
eval_result=classifier.evaluate(input_fn=lambda:iris_data.eval_input_fn(test_x,test_y,1))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-12-05:49:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Rahul\AppData\Local\Temp\tmpy5ov2u4a\model.ckpt-700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-12-05:49:31
# INFO:tensorflow:Saving dict for global step 700: accuracy = 0.96666664, average_loss = 0.18995307, global_step = 700, loss = 0.18995307
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 700: C:\Users\Rahul\AppData\Local\Temp\tmpy5ov2u4a\model.ckpt-700

# %%
print(eval_result)
# Out:
# {'accuracy': 0.96666664, 'average_loss': 0.18995307, 'loss': 0.18995307, 'global_step': 700}
